# %%
import pandas as pd
from google.colab import files
dp=files.upload()
# Out:
#      <input type="file" id="files-da6dd807-40b3-4f51-80cf-ea039ebd44c0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-da6dd807-40b3-4f51-80cf-ea039ebd44c0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data=pd.read_excel(r"Book1.xlsx")
data
# Out:
#     Name  Age City  Marks
# 0    sam   20  CBE   29.0
# 1    ram   19  MDX   68.0
# 2   ishu   22  CHN   57.0
# 3   nivi   12  RJS    NaN
# 4  mahii   45  GJT   66.0
# 5  kavin   34  CHN   74.0
# 6  kevin   28  CBE   84.0
# 7    ram   19  MDX   68.0
# 8   diya   39  NaN   74.0
# 9  dhyam   24  NaN   61.0

# %%
df=pd.DataFrame(data)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    10 non-null     object
#  1   Age     10 non-null     int64
#  2   City    8 non-null      object
#  3   Marks   9 non-null      float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 452.0+ bytes

# %%
df.isnull()
# Out:
#     Name    Age   City  Marks
# 0  False  False  False  False
# 1  False  False  False  False
# 2  False  False  False  False
# 3  False  False  False   True
# 4  False  False  False  False
# 5  False  False  False  False
# 6  False  False  False  False
# 7  False  False  False  False
# 8  False  False   True  False
# 9  False  False   True  False

# %%
df.isnull().sum()
# Out:
# Name     0
# Age      0
# City     2
# Marks    1
# dtype: int64

# %%
df.describe()
# Out:
#              Age      Marks
# count  10.000000   9.000000
# mean   26.200000  64.555556
# std    10.261037  15.476685
# min    12.000000  29.000000
# 25%    19.250000  61.000000
# 50%    23.000000  68.000000
# 75%    32.500000  74.000000
# max    45.000000  84.000000

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7     True
# 8    False
# 9    False
# dtype: bool

# %%
df.drop_duplicates()
# Out:
#     Name  Age City  Marks
# 0    sam   20  CBE   29.0
# 1    ram   19  MDX   68.0
# 2   ishu   22  CHN   57.0
# 3   nivi   12  RJS    NaN
# 4  mahii   45  GJT   66.0
# 5  kavin   34  CHN   74.0
# 6  kevin   28  CBE   84.0
# 8   diya   39  NaN   74.0
# 9  dhyam   24  NaN   61.0

# %%
df.dropna() #removes_blank_space
# Out:
#     Name  Age City  Marks
# 0    sam   20  CBE   29.0
# 1    ram   19  MDX   68.0
# 2   ishu   22  CHN   57.0
# 4  mahii   45  GJT   66.0
# 5  kavin   34  CHN   74.0
# 6  kevin   28  CBE   84.0
# 7    ram   19  MDX   68.0

# %%
df.fillna("No records") #fill blank with input string
# Out:
#     Name  Age        City       Marks
# 0    sam   20         CBE        29.0
# 1    ram   19         MDX        68.0
# 2   ishu   22         CHN        57.0
# 3   nivi   12         RJS  No records
# 4  mahii   45         GJT        66.0
# 5  kavin   34         CHN        74.0
# 6  kevin   28         CBE        84.0
# 7    ram   19         MDX        68.0
# 8   diya   39  No records        74.0
# 9  dhyam   24  No records        61.0

# %%
df #print
# Out:
#     Name  Age City  Marks
# 0    sam   20  CBE   29.0
# 1    ram   19  MDX   68.0
# 2   ishu   22  CHN   57.0
# 3   nivi   12  RJS    NaN
# 4  mahii   45  GJT   66.0
# 5  kavin   34  CHN   74.0
# 6  kevin   28  CBE   84.0
# 7    ram   19  MDX   68.0
# 8   diya   39  NaN   74.0
# 9  dhyam   24  NaN   61.0

# %%
df['Marks'].fillna(0)
# Out:
# 0    29.0
# 1    68.0
# 2    57.0
# 3     0.0
# 4    66.0
# 5    74.0
# 6    84.0
# 7    68.0
# 8    74.0
# 9    61.0
# Name: Marks, dtype: float64

# %%
df['Marks']=df['Marks'].replace(66,0)
df
# Out:
#     Name  Age City  Marks
# 0    sam   20  CBE   29.0
# 1    ram   19  MDX   68.0
# 2   ishu   22  CHN   57.0
# 3   nivi   12  RJS    NaN
# 4  mahii   45  GJT    0.0
# 5  kavin   34  CHN   74.0
# 6  kevin   28  CBE   84.0
# 7    ram   19  MDX   68.0
# 8   diya   39  NaN   74.0
# 9  dhyam   24  NaN   61.0

# %%
df['Marks'].fillna(0,inplace=True)
# Out:
# /tmp/ipython-input-130461783.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Marks'].fillna(0,inplace=True)

# %%
df
# Out:
#     Name  Age City  Marks
# 0    sam   20  CBE   29.0
# 1    ram   19  MDX   68.0
# 2   ishu   22  CHN   57.0
# 3   nivi   12  RJS    0.0
# 4  mahii   45  GJT    0.0
# 5  kavin   34  CHN   74.0
# 6  kevin   28  CBE   84.0
# 7    ram   19  MDX   68.0
# 8   diya   39  NaN   74.0
# 9  dhyam   24  NaN   61.0

# %%
avg=df['Marks'].mean()

# %%
avg
# Out:
# np.float64(51.5)

# %%
df['City'].fillna("no rec")
# Out:
# 0       CBE
# 1       MDX
# 2       CHN
# 3       RJS
# 4       GJT
# 5       CHN
# 6       CBE
# 7       MDX
# 8    no rec
# 9    no rec
# Name: City, dtype: object

# %%
df["City"].fillna('no rec',inplace=True)
# Out:
# /tmp/ipython-input-4105794052.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["City"].fillna('no rec',inplace=True)

# %%
df
# Out:
#     Name  Age    City  Marks
# 0    sam   20     CBE   29.0
# 1    ram   19     MDX   68.0
# 2   ishu   22     CHN   57.0
# 3   nivi   12     RJS    0.0
# 4  mahii   45     GJT    0.0
# 5  kavin   34     CHN   74.0
# 6  kevin   28     CBE   84.0
# 7    ram   19     MDX   68.0
# 8   diya   39  no rec   74.0
# 9  dhyam   24  no rec   61.0

# %%
df['City'].replace('no rec','RJS')
# Out:
# 0    CBE
# 1    MDX
# 2    CHN
# 3    RJS
# 4    GJT
# 5    CHN
# 6    CBE
# 7    MDX
# 8    RJS
# 9    RJS
# Name: City, dtype: object

# %%
mavg=df['Marks'].mean()

# %%
mavg
# Out:
# np.float64(51.5)

# %%
df.to_csv("Book1.csv")

# %%
files.download("Book1.csv")

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['City'],df['Marks'])
plt.title("City vs Marks")
plt.xlabel("City")
plt.ylabel("Marks")
plt.show()
plt.show()

# %%
plt.bar(df['City'],df['Marks'])
plt.title("City vs Marks")
plt.xlabel("City")
plt.ylabel("Marks")
plt.show()

# %%
plt.pie(df['Marks'],labels=df['City'])
plt.title("Marks")
plt.show()

# %%
plt.plot(df['City'],df['Marks'])
plt.title("City vs Marks")
plt.xlabel("City")
plt.ylabel("Marks")
plt.show()

# %%
plt.hist(df['Marks'])
plt.title("Marks")
plt.xlabel("Marks")
plt.ylabel("Frequency")
plt.show()

# %%
plt.hist(df['Marks'],bins=5)
plt.title("Marks")
plt.xlabel("Marks")
plt.ylabel("Frequency")
plt.show()

# %%
plt.boxplot(df['Marks'])
plt.title("Marks")
plt.xlabel("Marks")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.hist(df['Marks'])
plt.title("Marks")
plt.xlabel("Marks")
plt.ylabel("Frequency")
plt.show()

# %%
plt.subplot(1,2,2)
plt.boxplot(df['Marks'])
plt.title("Marks")
plt.xlabel("Marks")
plt.ylabel("Frequency")
plt.show()

plt.subplot(1,2,1)
plt.hist(df['Marks'])
plt.title("Marks")
plt.xlabel("Marks")
plt.ylabel("Frequency")

plt.subplot(1,2,2)
plt.pie(df['Marks'],labels=df['City'])
plt.title("Marks")
plt.show()


plt.scatter(df['City'],df['Marks'])
plt.title("City vs Marks")
plt.xlabel("City")
plt.ylabel("Marks")
plt.show()

# %%
plt.subplot(1,2,1)
plt.hist(df['Marks'])
plt.title("Marks")
plt.xlabel("Marks")
plt.ylabel("Frequency")

plt.subplot(1,2,2)
plt.pie(df['Marks'],labels=df['City'])
plt.title("Marks")
plt.show()


plt.scatter(df['City'],df['Marks'])
plt.title("City vs Marks")
plt.xlabel("City")
plt.ylabel("Marks")
plt.show()

# %%
plt.subplot(1,2,1)
plt.hist(df['Marks'])
plt.title("Marks")
plt.xlabel("Marks")
plt.ylabel("Frequency")

plt.subplot(1,2,2)
plt.pie(df['Marks'],labels=df['City'])
plt.title("Marks")
plt.show()

plt.subplot(2,2,1)
plt.scatter(df['City'],df['Marks'])
plt.title("City vs Marks")
plt.xlabel("City")
plt.ylabel("Marks")
plt.show()

plt.subplot(2,2,2)
plt.plot(df['City'],df['Marks'])
plt.title("City vs Marks")
plt.xlabel("City")
plt.ylabel("Marks")
plt.show()

# %%
files.download("Book1.csv")
